# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline

# %%
#importing csv file(dataset) in df
df=pd.read_csv("C:\\Users\\Kunj\\Downloads\\wine_dataset\\winequalityN.csv")

# %%
#top 5 values of dataset
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
#finding null values
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
#finding min,max,mean etc.. usinng describe function
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
#finding info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
#finding values counts of "type" column 
df['type'].value_counts()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
#fill null values in blank columns(fixed acidity) with mean
df['fixed acidity'].fillna(df['fixed acidity'].mean(),inplace=True)

# %%
#fill null values in blank column(volatile acidity) with median
df['volatile acidity'].fillna(df['volatile acidity'].median(),inplace=True)

# %%
#fill null values in blank column(citric acid) with median
df['citric acid'].fillna(df['citric acid'].median(),inplace=True)

# %%
#fill null values in blank column(residual sugar) with median
df['residual sugar'].fillna(df['residual sugar'].median(),inplace=True)

# %%
#fill null values in blank column(chlorides) with median
df['chlorides'].fillna(df['chlorides'].median(),inplace=True)

# %%
#fill null values in blank column(pH) with median
df['pH'].fillna(df['pH'].median(),inplace=True)

# %%
#fill null values in blank column(chlorides) with median
df['chlorides'].fillna(df['chlorides'].median(),inplace=True)

# %%
#fill null values in blank column(chlorides) with median
df['sulphates'].fillna(df['sulphates'].median(),inplace=True)

# %%
#finding null values
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# finding dublicate values in dataset
df.duplicated().sum()
# Out:
# 1168

# %%
#droping dublicate vales
df.drop_duplicates(inplace=True)

# %%
# finding dublicate values in dataset
df.duplicated().sum()
# Out:
# 0

# %%
#Creating count plot of type column
sns.countplot('type',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df.groupby(['type','alcohol'])['alcohol'].count()
# Out:
# type   alcohol
# red    8.40        2
#        8.50        1
#        8.70        2
#        8.80        1
#        9.00       21
#                   ..
# white  13.80       2
#        13.90       3
#        14.00       5
#        14.05       1
#        14.20       1
# Name: alcohol, Length: 168, dtype: int64

# %%
#creating bar plot of alcohol and type 
sns.barplot(y='alcohol',x='type',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='alcohol'>

# %%
#barplot of all data behalf of type
fig,arr=plt.subplots(6,2,figsize=(20,12),dpi=300)
sns.barplot(y='fixed acidity',x='type',hue='type',data=df, ax=arr[0][0])
sns.barplot(y='volatile acidity',x='type',hue='type',data=df, ax=arr[0][1])
sns.barplot(y='citric acid',x='type',hue='type',data=df, ax=arr[1][0])
sns.barplot(y='residual sugar',x='type',hue='type',data=df, ax=arr[1][1])
sns.barplot(y='chlorides',x='type',hue='type',data=df, ax=arr[2][0])
sns.barplot(y='free sulfur dioxide',x='type',hue='type',data=df, ax=arr[2][1])
sns.barplot(y='total sulfur dioxide',x='type',hue='type',data=df, ax=arr[3][0])
sns.barplot(y='density',x='type',hue='type',data=df, ax=arr[3][1])
sns.barplot(y='pH',x='type',hue='type',data=df, ax=arr[4][0])
sns.barplot(y='sulphates',x='type',hue='type',data=df, ax=arr[4][1])
sns.barplot(y='alcohol',x='type',hue='type',data=df, ax=arr[5][0])
sns.barplot(y='quality',x='type',hue='type',data=df, ax=arr[5][1])
# Out:
# <AxesSubplot:xlabel='type', ylabel='quality'>

# %%
#histplot of all data behalf of type
fig,arr=plt.subplots(6,2,figsize=(20,12),dpi=300)
sns.histplot(data=df,x='type',bins=60, ax=arr[0][0])
sns.histplot(data=df,x='fixed acidity',bins=60, ax=arr[0][1])
sns.histplot(data=df,x='volatile acidity',bins=60, ax=arr[1][0])
sns.histplot(data=df,x='citric acid',bins=60, ax=arr[1][1])
sns.histplot(data=df,x='residual sugar',bins=60, ax=arr[2][0])
sns.histplot(data=df,x='chlorides',bins=60, ax=arr[2][1])
sns.histplot(data=df,x='free sulfur dioxide',bins=60, ax=arr[3][0])
sns.histplot(data=df,x='total sulfur dioxide',bins=60, ax=arr[3][1])
sns.histplot(data=df,x='density',bins=60, ax=arr[4][0])
sns.histplot(data=df,x='pH',bins=60, ax=arr[4][1])
sns.histplot(data=df,x='sulphates',bins=60, ax=arr[5][0])
sns.histplot(data=df,x='alcohol',bins=60, ax=arr[5][0])
sns.histplot(data=df,x='quality',bins=60, ax=arr[5][0])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Count'>

# %%
#boxplot of all data behalf of type
fig,arr=plt.subplots(6,2,figsize=(20,10),dpi=300)
sns.boxplot(y='fixed acidity',x='type',hue='type',data=df, ax=arr[0][0])
sns.boxplot(y='volatile acidity',x='type',hue='type',data=df, ax=arr[0][1])
sns.boxplot(y='citric acid',x='type',hue='type',data=df, ax=arr[1][0])
sns.boxplot(y='residual sugar',x='type',hue='type',data=df, ax=arr[1][1])
sns.boxplot(y='chlorides',x='type',hue='type',data=df, ax=arr[2][0])
sns.boxplot(y='free sulfur dioxide',x='type',hue='type',data=df, ax=arr[2][1])
sns.boxplot(y='total sulfur dioxide',x='type',hue='type',data=df, ax=arr[3][0])
sns.boxplot(y='density',x='type',hue='type',data=df, ax=arr[3][1])
sns.boxplot(y='pH',x='type',hue='type',data=df, ax=arr[4][0])
sns.boxplot(y='sulphates',x='type',hue='type',data=df, ax=arr[4][1])
sns.boxplot(y='alcohol',x='type',hue='type',data=df, ax=arr[5][0])
sns.boxplot(y='quality',x='type',hue='type',data=df, ax=arr[5][1])
# Out:
# <AxesSubplot:xlabel='type', ylabel='quality'>

# %%
#info funtion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5329 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5329 non-null   object
#  1   fixed acidity         5329 non-null   float64
#  2   volatile acidity      5329 non-null   float64
#  3   citric acid           5329 non-null   float64
#  4   residual sugar        5329 non-null   float64
#  5   chlorides             5329 non-null   float64
#  6   free sulfur dioxide   5329 non-null   float64
#  7   total sulfur dioxide  5329 non-null   float64
#  8   density               5329 non-null   float64
#  9   pH                    5329 non-null   float64
#  10  sulphates             5329 non-null   float64
#  11  alcohol               5329 non-null   float64
#  12  quality               5329 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 582.9+ KB

# %%
# bar plot of residual sugar and type
sns.barplot(y='residual sugar',x='type',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='residual sugar'>

# %%
#describe function
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5329.000000       5329.000000  5329.000000     5329.000000
# mean        7.216573          0.344042     0.318733        5.053068
# std         1.317955          0.168115     0.147075        4.503336
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5329.000000          5329.000000           5329.000000  5329.000000
# mean      0.056665            30.060143            114.189341     0.994536
# std       0.036838            17.815588             56.781422     0.002966
# ...

# %%
#heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#histplot of alcohol
plt.figure(figsize=(10,5),dpi=150)
sns.histplot(data=df,x='alcohol',bins=60)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
df['type'].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %% [markdown]
# #making data for modeling

# %%
#map funtion
df['type']=df['type'].map({'white':0, 'red':1})

# %%
#data ready for modeling
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5329 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5329 non-null   int64
#  1   fixed acidity         5329 non-null   float64
#  2   volatile acidity      5329 non-null   float64
#  3   citric acid           5329 non-null   float64
#  4   residual sugar        5329 non-null   float64
#  5   chlorides             5329 non-null   float64
#  6   free sulfur dioxide   5329 non-null   float64
#  7   total sulfur dioxide  5329 non-null   float64
#  8   density               5329 non-null   float64
#  9   pH                    5329 non-null   float64
#  10  sulphates             5329 non-null   float64
#  11  alcohol               5329 non-null   float64
#  12  quality               5329 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 711.9 KB
